# %%
import requests
import json
from pyspark.sql import SparkSession

#url = "https://disease.sh/v3/covid-19/all"
url =  "https://disease.sh/v3/covid-19/countries"


response = requests.get(url)

if response.status_code ==200:
    data = response.json()



# Save JSON to a file in Lakehouse (Files section)
    file_path = '/lakehouse/default/Files/Covid_bronze.json'  # Fabric DBFS path

    with open(file_path, "w") as f:
        json.dump(data, f, indent=4)

    print("data loaded")

else:
    print("not load", response.status_code)
# Out:
# StatementMeta(, 6b986f70-4192-472f-bc92-4ef6a5b4c736, 3, Finished, Available, Finished)
# data loaded

# %%
df = spark.read.option("multiline", "true").json("Files/Covid_bronze.json")
# df now is a Spark DataFrame containing JSON data from "Files/Covid_bronze.json".
display(df)
# Out:
# StatementMeta(, 6b986f70-4192-472f-bc92-4ef6a5b4c736, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6b6de0b1-f982-439f-abc9-563725f37cbd)
